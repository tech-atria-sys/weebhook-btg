# %%
import requests

# 1. A URL que está aparecendo na sua tela preta do Ngrok AGORA
# (Adicionei o /webhook no final, que é obrigatório)
URL_NGROK = "https://unranging-arlinda-secretively.ngrok-free.dev/webhook"

# 2. Um JSON falso fingindo ser o BTG
payload_falso = {
    "response": {
        "url": "https://www.google.com/robots.txt", # Link falso só pra testar download
        "startDate": "2024-01-01",
        "endDate": "TESTE-DE-SOM"
    }
}

print(f"📣 Gritando 'Alô' para: {URL_NGROK}...")

try:
    r = requests.post(URL_NGROK, json=payload_falso)
    
    if r.status_code == 200:
        print("✅ O Ngrok respondeu 200 OK!")
        print("👀 CORRA e olhe a janela do seu servidor Python (Porteiro).")
        print("Ela deve ter acordado e tentado baixar um arquivo.")
    else:
        print(f"❌ O Ngrok rejeitou: {r.status_code}")
        print(r.text)

except Exception as e:
    print(f"❌ Falha ao conectar: {e}")
# Out:
# 📣 Gritando 'Alô' para: https://unranging-arlinda-secretively.ngrok-free.dev/webhook...
# ✅ O Ngrok respondeu 200 OK!
# 👀 CORRA e olhe a janela do seu servidor Python (Porteiro).
# Ela deve ter acordado e tentado baixar um arquivo.
